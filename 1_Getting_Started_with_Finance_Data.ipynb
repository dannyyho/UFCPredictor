# %% [markdown]
# <a href="https://colab.research.google.com/github/dannyyho/UFCPredictor/blob/main/1_Getting_Started_with_Finance_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Yahoo Finance
# Stock Index, eg, ^GSPC
# Curreny Exchange rate, e.g, GBPUSD=X
# Options,

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yfinance
#   Downloading yfinance-0.1.72-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.9.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 7.9 MB/s
# Collecting requests>=2.26
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.28.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.9.1 requests-2.28.1 yfinance-0.1.72

# %%
import yfinance as yf

#single Stock
RBC = yf.download('RY', 
                       start='2022-07-01', 
                       end='2022-07-08')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
RBC.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2022-07-01  96.419998  97.809998  96.010002  97.449997  97.449997  623500
# 2022-07-05  96.160004  96.500000  94.290001  95.769997  95.769997  995500
# 2022-07-06  95.809998  96.449997  95.080002  96.250000  96.250000  775100
# 2022-07-07  96.949997  98.769997  96.889999  98.239998  98.239998  850300

# %% [markdown]
# # You can also get other stock data, eg, minute-by-minute, or monthly ...

# %%
#Several stocks
tickers =['RY']

start_date='2022-01-01'
end_date='2022-07-08'

df_yf=yf.download(
        # tickers list or string as well
        tickers,

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1d",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC (open, high, low, closing) automatically
        # (optional, default is False)
        #auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df_yf.head
# Out:
# <bound method NDFrame.head of                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  106.410004  107.540001  106.410004  107.070000  105.253716
# 2022-01-04  107.220001  108.059998  106.709999  107.570000  105.745239
# 2022-01-05  107.690002  109.529999  107.690002  108.339996  106.502174
# 2022-01-06  108.790001  110.019997  108.610001  109.910004  108.045547
# 2022-01-07  110.250000  112.389999  110.209999  112.129997  110.227882
# ...                ...         ...         ...         ...         ...
# 2022-07-01   96.419998   97.809998   96.010002   97.449997   97.449997
# 2022-07-05   96.160004   96.500000   94.290001   95.769997   95.769997
# 2022-07-06   95.809998   96.449997   95.080002   96.250000   96.250000
# 2022-07-07   96.949997   98.769997   96.889999   98.239998   98.239998
# 2022-07-08   98.239998   99.150002   97.910004   98.419998   98.419998
#
#              Volume
# Date
# 2022-01-03  1515900
# 2022-01-04  1909600
# 2022-01-05  1279500
# 2022-01-06  1196600
# 2022-01-07  1527700
# ...             ...
# 2022-07-01   623500
# 2022-07-05   995500
# 2022-07-06   775100
# 2022-07-07   850300
# 2022-07-08   616600
#
# [129 rows x 6 columns]>

# %%
df_yf['Adj Close'].plot(figsize=(12,8))

# %%
df_yf['Adj Close'].plot(figsize=(12,8))

# %%
df_yf=yf.download('RY', start_date, end_date)

# %%
df_yf.head

# %%
df_yf['Adj Close'].plot(figsize=(12,8))

# %% [markdown]
# # You can also use pandas_datareader

# %%
import pandas_datareader 
from pandas_datareader import data

# Fetch daily data for 4 years
symbol='RY'
start_date = '2022-01-01'
end_date = '2022-06-30'

df_pd = data.DataReader(symbol, 'yahoo', start_date, end_date)
df_pd.head()
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-22-2617d4c127ed> in <module>()
#       7 end_date = '2022-06-30'
#       8
# ----> 9 df_pd = data.DataReader(symbol, 'yahoo', start_date, end_date)
#      10 df_pd.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     382             retry_count=retry_count,
#     383             pause=pause,
# --> 384             session=session,
#     385         ).read()
#     386
#
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py in read(self)
#     251         # If a single symbol, (e.g., 'GOOG')
#     252         if isinstance(self.symbols, (string_types, int)):
# --> 253             df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254         # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255         elif isinstance(self.symbols, DataFrame):
#
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/yahoo/daily.py in _read_one_data(self, url, params)
#     151         url = url.format(symbol)
#     152
# --> 153         resp = self._get_response(url, params=params)
#     154         ptrn = r"root\.App\.main = (.*?);\n}\(this\)\);"
#     155         try:
#
# /usr/local/lib/python3.7/dist-packages/pandas_datareader/base.py in _get_response(self, url, params, headers)
#     179             msg += "\nResponse Text:\n{0}".format(last_response_text)
#     180
# --> 181         raise RemoteDataError(msg)
#     182
#     183     def _get_crumb(self, *args):
#
# RemoteDataError: Unable to read URL: https://finance.yahoo.com/quote/RY/history?period1=1641009600&period2=1656647999&interval=1d&frequency=1d&filter=history
# Response Text:
# b'<!DOCTYPE html>\n  <html lang="en-us"><head>\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n      <meta charset="utf-8">\n      <title>Yahoo</title>\n      <meta name="viewport" content="width=device-width,initial-scale=1,minimal-ui">\n      <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n      <style>\n  html {\n      height: 100%;\n  }\n  body {\n      background: #fafafc url(https://s.yimg.com/nn/img/sad-panda-201402200631.png) 50% 50%;\n      background-size: cover;\n      height: 100%;\n      text-align: center;\n      font: 300 18px "helvetica neue", helvetica, verdana, tahoma, arial, sans-serif;\n  }\n  table {\n      height: 100%;\n      width: 100%;\n      table-layout: fixed;\n      border-collapse: collapse;\n      border-spacing: 0;\n      border: none;\n  }\n  h1 {\n      font-size: 42px;\n      font-weight: 400;\n      color: #400090;\n  }\n  p {\n      color: #1A1A1A;\n  }\n  #message-1 {\n      font-weight: bold;\n      margin: 0;\n  }\n  #message-2 {\n      display: inline-block;\n      *display: inline;\n      zoom: 1;\n      max-width: 17em;\n      _width: 17em;\n  }\n      </style>\n  <script>\n    document.write(\'<img src="//geo.yahoo.com/b?s=1197757129&t=\'+new Date().getTime()+\'&src=aws&err_url=\'+encodeURIComponent(document.URL)+\'&err=%<pssc>&test=\'+encodeURIComponent(\'%<{Bucket}cqh[:200]>\')+\'" width="0px" height="0px"/>\');var beacon = new Image();beacon.src="//bcn.fp.yahoo.com/p?s=1197757129&t="+ne...

# %%
df_pd['Adj Close'].plot(figsize=(12,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # You can also get company info

# %%
RBC=yf.Ticker('RY')

# %%
RBC.info
# Out:
# {'52WeekChange': -0.03961748,
#  'SandP52WeekChange': -0.110670686,
#  'address1': '200 Bay Street',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 99.87,
#  'askSize': 900,
#  'averageDailyVolume10Day': 842140,
#  'averageVolume': 988888,
#  'averageVolume10days': 842140,
#  'beta': 0.77265,
#  'beta3Year': None,
#  'bid': 96,
#  'bidSize': 900,
#  'bookValue': 69.201,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Toronto',
#  'coinMarketCapLink': None,
#  'companyOfficers': [],
#  'country': 'Canada',
#  'currency': 'USD',
#  'currentPrice': 98.42,
#  'currentRatio': None,
#  'dateShortInterest': 1655251200,
#  'dayHigh': 99.14,
#  'dayLow': 97.94,
#  'debtToEquity': None,
#  'dividendRate': 3.99,
#  'dividendYield': 0.040599998,
#  'earningsGrowth': 0.072,
#  'earningsQuarterlyGrowth': 0.059,
#  'ebitda': None,
#  'ebitdaMargins': 0,
#  'enterpriseToEbitda': None,
#  'enterpriseToRevenue': -2.957,
#  'enterpriseValue': -149102526464,
#  'exDividendDate': 1658707200,
#  'exchange': 'NYQ',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'expireDate': None,
#  'fiftyDayAverage': 99.7406,
#  'fiftyTwoWeekHigh': 119.41,
#  'fiftyTwoWeekLow': 94.23,
#  'financialCurrency': 'CAD',
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 3.78,
#  'floatShares': 1401953787,
#  'forwardEps': 9.29,
#  'forwardPE': 10.594187,
#  'freeCashflow': None,
#  'fromCurrency': None,
#  'fullTimeEmployees': 86007,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '-14400000',
#  'grossMargins': 0,
#  'grossProfits': 50446000000,
#  'heldPercentInsiders': 0.00011,
#  'heldPercentInstitutions': 0.47887,
#  'impliedSharesOutstanding': 0,
#  'industry': 'Banks—Diversified',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1650585600,
#  'lastDividendValue': 0.954,
#  'lastFiscalYearEnd': 1635638400,
#  'lastMarket': None,
#  'lastSplitDate': 1144368000,
#  'lastSplitFactor': '2:1',
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/rbc.com',
#  'longBusinessSummary': "Royal Bank of Canada operates as a diversified financial service company worldwide. The company's Personal & Commercial Banking segment offers checking and savings accounts, home equity financing, personal lending, private banking, indirect lending, including auto financing, mutual funds and self-directed brokerage accounts, guaranteed investment certificates, credit cards, and payment products and solutions; and lending, leasing, deposit, investment, foreign exchange, cash management, auto dealer financing, trade products, and services to small and medium-sized commercial businesses. This segment offers financial products and services through branches, automated teller machines, and mobile sales network. Its Wealth Management segment provides a suite of advice-based solutions and strategies to high net worth and ultra-high net worth individuals, and institutional clients. The company's Insurance segment offers life, health, home, auto, travel, wealth, annuities, and reinsurance advice and solutions; and business insurance services to individual, business, and group clients through its advice centers, RBC insurance stores, and mobile advisors; digital, mobile, and social platforms; independent brokers; and travel partners. Its Investor & Treasury Services segment provides asset servicing, custody, payments, and treasury services to financial and other investors; and fund and investment administration, shareholder, private capital, performance measurement and compliance monitoring, distribution, transaction banking, cash and liquidity management, foreign exchange, and global securities finance services. The company's Capital Markets segment offers corporate and investment banking, as well as equity and debt origination, distribution, advisory services, sale, and trading services for corporations, institutional investors, asset managers, private equity firms, and governments. The company was founded in 1864 and is headquartered in Toronto, Canada.",
#  'longName': 'Royal Bank of Canada',
#  'market': 'us_market',
#  'marketCap': 137995665408,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_109809',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1651276800,
#  'navPrice': None,
#  'netIncomeToCommon': 16277000192,
#  'nextFiscalYearEnd': 1698710400,
#  'numberOfAnalystOpinions': 4,
#  'open': 98.24,
#  'openInterest': None,
#  'operatingCashflow': -72919998464,
#  'operatingMargins': 0.44772,
#  'payoutRatio': 0.3986,
#  'pegRatio': 1.22,
#  'preMarketPrice': None,
#  'previousClose': 98.24,
#  'priceHint': 2,
#  'priceToBook': 1.4222338,
#  'priceToSalesTrailing12Months': 2.7368145,
#  'profitMargins': 0.32766998,
#  'quickRatio': None,
#  'quoteType': 'EQUITY',
#  'recommendationKey': 'buy',
#  'recommendationMean': 2.5,
#  'regularMarketDayHigh': 99.14,
#  'regularMarketDayLow': 97.94,
#  'regularMarketOpen': 98.24,
#  'regularMarketPreviousClose': 98.24,
#  'regularMarketPrice': 98.42,
#  'regularMarketVolume': 616602,
#  'returnOnAssets': 0.00955,
#  'returnOnEquity': 0.16768,
#  'revenueGrowth': -0.013,
#  'revenuePerShare': 35.503,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Financial Services',
#  'sharesOutstanding': 1402109952,
#  'sharesPercentSharesOut': 0.0047999998,
#  'sharesShort': 6727525,
#  'sharesShortPreviousMonthDate': 1652400000,
#  'sharesShortPriorMonth': 12615157,
#  'shortName': 'Royal Bank Of Canada',
#  'shortPercentOfFloat': None,
#  'shortRatio': 6.8,
#  'startDate': None,
#  'state': 'ON',
#  'strikePrice': None,
#  'symbol': 'RY',
#  'targetHighPrice': 114.29,
#  'targetLowPrice': 107.78,
#  'targetMeanPrice': 111.51,
#  'targetMedianPrice': 111.99,
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'totalCash': 735652020224,
#  'totalCashPerShare': 524.676,
#  'totalDebt': 441154994176,
#  'totalRevenue': 50422001664,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 4.56,
#  'trailingAnnualDividendYield': 0.04641694,
#  'trailingEps': 8.78,
#  'trailingPE': 11.209567,
#  'twoHundredDayAverage': 105.6134,
#  'volume': 616602,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'https://www.rbc.com',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': 'M5J 2J5'}

# %%
RBC.history(period="max")
# Out:
#                  Open       High        Low      Close  Volume  Dividends  \
# Date
# 1995-10-16   2.095468   2.118244   2.095468   2.118244   62000        0.0
# 1995-10-17   2.118244   2.118244   2.118244   2.118244   53200        0.0
# 1995-10-18   2.106856   2.129633   2.106856   2.118244   72000        0.0
# 1995-10-19   2.129633   2.129633   2.118244   2.118244    5200        0.0
# 1995-10-20   2.084080   2.084080   2.061303   2.061303   16400        0.0
# ...               ...        ...        ...        ...     ...        ...
# 2022-07-01  96.419998  97.809998  96.010002  97.449997  623500        0.0
# 2022-07-05  96.160004  96.500000  94.290001  95.769997  995500        0.0
# 2022-07-06  95.809998  96.449997  95.080002  96.250000  775100        0.0
# 2022-07-07  96.949997  98.769997  96.889999  98.239998  850300        0.0
# 2022-07-08  98.239998  99.150002  97.910004  98.419998  616600        0.0
#
#             Stock Splits
# Date
# 1995-10-16           0.0
# 1995-10-17           0.0
# 1995-10-18           0.0
# 1995-10-19           0.0
# 1995-10-20           0.0
# ...                  ...
# 2022-07-01           0.0
# 2022-07-05           0.0
# 2022-07-06           0.0
# 2022-07-07           0.0
# 2022-07-08           0.0
#
# [6729 rows x 7 columns]

# %% [markdown]
# # List the dividend payments and stock splits:  corporate action

# %%
RBC.actions
# Out:
#             Dividends  Stock Splits
# Date
# 1996-07-22     0.0850           0.0
# 1996-10-22     0.0850           0.0
# 1997-01-23     0.0925           0.0
# 1997-04-22     0.0925           0.0
# 1997-07-22     0.0975           0.0
# ...               ...           ...
# 2021-04-21     0.8570           0.0
# 2021-07-23     0.8600           0.0
# 2021-10-25     0.8740           0.0
# 2022-01-25     0.9500           0.0
# 2022-04-22     0.9540           0.0
#
# [104 rows x 2 columns]

# %%
RBC.dividends
# Out:
# Date
# 1996-07-22    0.0850
# 1996-10-22    0.0850
# 1997-01-23    0.0925
# 1997-04-22    0.0925
# 1997-07-22    0.0975
#                ...
# 2021-04-21    0.8570
# 2021-07-23    0.8600
# 2021-10-25    0.8740
# 2022-01-25    0.9500
# 2022-04-22    0.9540
# Name: Dividends, Length: 102, dtype: float64

# %%
RBC.splits
# Out:
# Date
# 2000-10-06    2.0
# 2006-04-07    2.0
# Name: Stock Splits, dtype: float64

# %% [markdown]
# # PE ratio, etc

# %%
RBC.info['forwardPE']
# Out:
# 10.594187

# %%
RBC.info['trailingPE']
# Out:
# 11.209567

# %% [markdown]
# # Download Futures Price

# %%
data = yf.download("CLK23.NYM, CLK24.NYM", start="2015-01-01", end="2022-02-18") 
data['Close'].plot(figsize=(12,8))
# Out:
# [*********************100%***********************]  2 of 2 completed
# <AxesSubplot:xlabel='Date'>

# %%
#May 2020 Crude Oil Futures
#data = yf.download("CLK20.NYM")
#data.head
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CLK20.NYM: No data found, symbol may be delisted
# <bound method NDFrame.head of Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []>

# %% [markdown]
# # Download options data using yfinance
# ## First, let us look at what maturity dates are traded

# %%
#expiry dates for options for a particular ticker 
RBC.options
# Out:
# ('2022-07-15', '2022-08-19', '2022-10-21', '2023-01-20', '2024-01-19')

# %%
#Also allook at SP500 
spx=yf.Ticker('^SPX')
spx.info
# Out:
# {'exchange': 'WCB',
#  'shortName': 'S&P 500 INDEX',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'underlyingSymbol': '^GSPC',
#  'quoteType': 'INDEX',
#  'symbol': '^SPX',
#  'market': 'us_market',
#  'previousClose': 4017.82,
#  'regularMarketOpen': 3974.39,
#  'twoHundredDayAverage': None,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': None,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 3974.39,
#  'navPrice': None,
#  'averageDailyVolume10Day': None,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 4017.82,
#  'fiftyDayAverage': None,
#  'trailingAnnualDividendRate': None,
#  'open': 3974.39,
#  'toCurrency': None,
#  'averageVolume10days': None,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'beta': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 3900.16,
#  'priceHint': 2,
#  'currency': 'USD',
#  'regularMarketVolume': 2476966281,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': None,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': None,
#  'priceToSalesTrailing12Months': None,
#  'dayLow': 3900.16,
#  'ask': 3927.93,
#  'ytdReturn': None,
#  'askSize': 0,
#  'volume': 2476966281,
#  'fiftyTwoWeekHigh': 3974.39,
#  'forwardPE': None,
#  'maxAge': 1,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 3900.16,
#  'bid': 3878.48,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 3974.39,
#  'regularMarketPrice': 3900.86,
#  'preMarketPrice': None,
#  'logo_url': ''}

# %%
spx.options
# Out:
# ('2022-03-02',
#  '2022-03-04',
#  '2022-03-07',
#  '2022-03-09',
#  '2022-03-11',
#  '2022-03-14',
#  '2022-03-16',
#  '2022-03-18',
#  '2022-03-21',
#  '2022-03-23',
#  '2022-03-25',
#  '2022-03-28',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-08',
#  '2022-04-14',
#  '2022-04-29',
#  '2022-05-20',
#  '2022-05-31',
#  '2022-06-17',
#  '2022-06-30',
#  '2022-07-15',
#  '2022-07-29',
#  '2022-08-19',
#  '2022-09-16',
#  '2022-09-30',
#  '2022-10-21',
#  '2022-11-18',
#  '2022-12-16',
#  '2022-12-30',
#  '2023-01-20',
#  '2023-02-17',
#  '2023-03-17',
#  '2023-06-16',
#  '2023-12-15',
#  '2024-12-20',
#  '2025-12-19',
#  '2026-03-20',
#  '2026-12-18')

# %%
#Options expiring on a particular date - OPtion Chain
opt_chain = RBC.option_chain(date='2022-10-21')
opt_chain
# Out:
# Options(calls=      contractSymbol             lastTradeDate  strike  lastPrice   bid   ask  \
# 0  RY221021C00095000 2022-07-07 19:44:22+00:00    95.0       6.45  6.20  6.90
# 1  RY221021C00100000 2022-07-08 15:00:24+00:00   100.0       3.70  3.30  3.70
# 2  RY221021C00105000 2022-07-07 15:37:47+00:00   105.0       1.75  1.55  1.90
# 3  RY221021C00110000 2022-07-06 19:00:33+00:00   110.0       0.50  0.55  0.80
# 4  RY221021C00115000 2022-07-05 18:42:24+00:00   115.0       0.25  0.05  0.75
# 5  RY221021C00120000 2022-07-05 18:59:27+00:00   120.0       0.40  0.00  0.70
# 6  RY221021C00125000 2022-04-28 15:34:47+00:00   125.0       0.45  0.00  0.60
# 7  RY221021C00130000 2022-04-20 15:53:03+00:00   130.0       0.50  0.00  0.70
# 8  RY221021C00170000 2022-06-14 13:41:21+00:00   170.0       0.05  0.00  0.25
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0    0.05       0.781246       3             5           0.243172        True
# 1   -0.03      -0.804289       8           147           0.210457       False
# 2    0.00       0.000000       2           179           0.204842       False
# 3    0.00       0.000000      26           412           0.195809       False
# 4    0.00       0.000000       5          3220           0.240974       False
# 5    0.00       0.000000       4           333           0.280281       False
# 6    0.00       0.000000       1           620           0.309089       False
# 7    0.00       0.000000       1             6           0.358405       False
# 8    0.00       0.000000      33            27           0.498052       False
#
#   contractSize currency
# 0      REGULAR      USD
# 1      REGULAR      USD
# 2      REGULAR      USD
# 3      REGULAR      USD
# 4      REGULAR      USD
# 5      REGULAR      USD
# 6      REGULAR      USD
# 7      REGULAR      USD
# 8      REGULAR      USD  , puts=       contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25        True      REGULAR      USD
# 26        True      REGULAR      USD
# 27        True      REGULAR      USD
# 28        True      REGULAR      USD
# 29        True      REGULAR      USD
# 30        True      REGULAR      USD
# 31        True      REGULAR      USD

# %%
plt.plot(opt_chain.puts.strike, opt_chain.puts.lastPrice)
plt.xlabel('Strike Price')
plt.ylabel('Put Option Price')
plt.show()

# %% [markdown]
# #  Stock Indices
#
#  ## Dow-Jones Industrial Average

# %%
import pandas as pd

# There are 2 tables on the Wikipedia page,  we want the second table
#First table: description

components = \
pd.read_html('https://en.wikipedia.org/wiki/S%26P/TSX_60')

first_table = components[1]
second_table = components[0]
df = second_table
df
# Out:
#     Symbol                                            Company  \
# 0      AEM                         Agnico Eagle Mines Limited
# 1      AQN                  Algonquin Power & Utilities Corp.
# 2      ATD                      Alimentation Couche-Tard Inc.
# 3      BCE                                           BCE Inc.
# 4      BMO                                   Bank of Montreal
# 5      BNS                                Bank of Nova Scotia
# 6      ABX                           Barrick Gold Corporation
# 7      BHC                       Bausch Health Companies Inc.
# 8    BAM.A                   Brookfield Asset Management Inc.
# 9   BIP.UN            Brookfield Infrastructure Partners L.P.
# 10     CAE                                           CAE Inc.
# 11   CCL.B                                CCL Industries Inc.
# 12   GIB.A                                           CGI Inc.
# 13     CCO                                 Cameco Corporation
# 14  CAR.UN  Canadian Apartment Properties Real Estate Inve...
# 15      CM                 Canadian Imperial Bank of Commerce
# 16     CNR                  Canadian National Railway Company
# 17     CNQ                 Canadian Natural Resources Limited
# 18      CP                   Canadian Pacific Railway Limited
# 19   CTC.A                  Canadian Tire Corporation Limited
# 20    WEED                          Canopy Growth Corporation
# 21     CVE                                Cenovus Energy Inc.
# 22     CSU                        Constellation Software Inc.
# 23     DOL                                     Dollarama Inc.
# 24     EMA                                 Emera Incorporated
# 25     ENB                                      Enbridge Inc.
# 26      FM                        First Quantum Minerals Ltd.
# 27     FSV                           FirstService Corporation
# 28     FTS                                        Fortis Inc.
# 29     FNV                          Franco-Nevada Corporation
# 30      WN                              George Weston Limited
# 31     GIL                             Gildan Activewear Inc.
# 32     IMO                               Imperial Oil Limited
# 33       H                                  Hydro One Limited
# 34       K                           Kinross Gold Corporation
# 35       L                           Loblaw Companies Limited
# 36      MG                           Magna International Inc.
# 37     MFC                     Manulife Financial Corporation
# 38     MRU                                         Metro Inc.
# 39     NaN                            National Bank of Canada
# 40     NTR                                       Nutrien Ltd.
# 41    OTEX                              Open Text Corporation
# 42     PPL                       Pembina Pipeline Corporation
# 43     POW                        Power Corporation of Canada
# 44     QSR               Restaurant Brands International Inc.
# 45   RCI.B                         Rogers Communications Inc.
# 46      RY                               Royal Bank of Canada
# 47     SNC                             SNC-Lavalin Group Inc.
# 48     SAP                                        Saputo Inc.
# 49   SJR.B                           Shaw Communications Inc.
# 50    SHOP                                       Shopify Inc.
# 51     SLF                            Sun Life Financial Inc.
# 52      SU                                 Suncor Energy Inc.
# 53     TRP                              TC Energy Corporation
# 54  TECK.B                             Teck Resources Limited
# 55       T                                  Telus Corporation
# 56     TRI                        Thomson Reuters Corporation
# 57      TD                              Toronto-Dominion Bank
# 58     WCN                             Waste Connections Inc.
# 59     WPM                      Wheaton Precious Metals Corp.
#
#                     Sector
# 0          Basic Materials
# 1                Utilities
# 2         Consumer Staples
# 3   Communication Services
# 4       Financial Services
# 5       Financial Services
# 6          Basic Materials
# 7               Healthcare
# 8       Financial Services
# 9                Utilities
# 10             Industrials
# 11       Consumer Cyclical
# 12  Information Technology
# 13                  Energy
# 14             Real Estate
# 15      Financial Services
# 16             Industrials
# 17                  Energy
# 18             Industrials
# 19       Consumer Cyclical
# 20              Healthcare
# 21                  Energy
# 22  Information Technology
# 23        Consumer Staples
# 24               Utilities
# 25                  Energy
# 26         Basic Materials
# 27             Real Estate
# 28               Utilities
# 29         Basic Materials
# 30        Consumer Staples
# 31       Consumer Cyclical
# 32                  Energy
# 33               Utilities
# 34         Basic Materials
# 35        Consumer Staples
# 36       Consumer Cyclical
# 37      Financial Services
# 38        Consumer Staples
# 39      Financial Services
# 40         Basic Materials
# 41  Information Technology
# 42                  Energy
# 43      Financial Services
# 44       Consumer Cyclical
# 45  Communication Services
# 46      Financial Services
# 47             Industrials
# 48        Consumer Staples
# 49  Communication Services
# 50  Information Technology
# 51      Financial Services
# 52                  Energy
# 53                  Energy
# 54         Basic Materials
# 55  Communication Services
# 56             Industrials
# 57      Financial Services
# 58             Industrials
# 59         Basic Materials

# %%
yf.Ticker('DOL.TO').info
info = yf.Ticker('DOL.TO').info
marketcap = info['marketCap']
print(symbol, 'Market Cap: ', marketcap)
# Out:
# ATD Market Cap:  22690242560

# %% [markdown]
# # Market Cap

# %%
for symbol in df['Symbol']:
    sys=symbol.replace('.', '-')  #BRk.B --> BRK-B
    info = yf.Ticker(sys).info
    marketcap = info['marketCap']    
    print(symbol, 'Market Cap: ', marketcap)
# Out:
# AEM Market Cap:  20584239104
# AQN Market Cap:  9106857984
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-bbd525a8b3ce> in <module>()
#       2     sys=symbol.replace('.', '-')  #BRk.B --> BRK-B
#       3     info = yf.Ticker(sys).info
# ----> 4     marketcap = info['marketCap']
#       5     print(symbol, 'Market Cap: ', marketcap)
#
# KeyError: 'marketCap'

# %%
dd=pd.DataFrame(df)['Index weighting'].str.replace('%','')
pd.to_numeric(dd).sum()
# Out:
# 99.95

# %%
df[['Company', 'Symbol']]
# Out:
#                      Company Symbol
# 0                         3M    MMM
# 1           American Express    AXP
# 2                      Amgen   AMGN
# 3                      Apple   AAPL
# 4                     Boeing     BA
# 5                Caterpillar    CAT
# 6                    Chevron    CVX
# 7                      Cisco   CSCO
# 8                  Coca-Cola     KO
# 9                     Disney    DIS
# 10                       Dow    DOW
# 11             Goldman Sachs     GS
# 12                Home Depot     HD
# 13                 Honeywell    HON
# 14                       IBM    IBM
# 15                     Intel   INTC
# 16         Johnson & Johnson    JNJ
# 17            JPMorgan Chase    JPM
# 18                McDonald's    MCD
# 19                     Merck    MRK
# 20                 Microsoft   MSFT
# 21                      Nike    NKE
# 22          Procter & Gamble     PG
# 23                Salesforce    CRM
# 24                 Travelers    TRV
# 25              UnitedHealth    UNH
# 26                   Verizon     VZ
# 27                      Visa      V
# 28  Walgreens Boots Alliance    WBA
# 29                   Walmart    WMT

# %% [markdown]
# # Last Close price

# %%
import yfinance as yf

tickers =['RY.TO','DOL.TO','AC.TO']
df = pd.DataFrame(tickers, columns=['Symbol'])

for symbol in df['Symbol']:
    ticker_yahoo = yf.Ticker(symbol)
    data = ticker_yahoo.history(period='1d')
    last_quote = (data.tail(1)['Close'].iloc[0])
    print(symbol,round(last_quote,2))
# Out:
# RY.TO 127.56
# DOL.TO 78.29
# AC.TO 16.81

# %% [markdown]
# ## S&P 500 Stocks Composite Index

# %%
import pandas as pd

# There are 2 tables on the Wikipedia page, we want the first table
# second table shows the evolution of the changes

components = \
pd.read_html('https://en.wikipedia.org/wiki/List_of_S&P_500_companies')

first_table = components[0]
second_table = components[1]
sp_df = first_table
sp_df

# %%
sp_df[200:250]

# %%
yf.Ticker('INFO').history(period='1d')['Close']

# %% [markdown]
# # Last Closing Price

# %%
import warnings
warnings.filterwarnings("ignore")

## For some reason INFO has no data

SP500_Current_Price=[]

for symbol in sp_df['Symbol']:
    try:
    #if symbol != 'INFO':
        sym=symbol.replace('.', '-')  #For dual shares, eg, BRK.B, we have to change it to BRK-B
        ticker_yahoo = yf.Ticker(sym)
        data = ticker_yahoo.history(period='1d')
        last_quote = (data.tail(1)['Close'].iloc[0])
        SP500_Current_Price.append(
            {
                #     'Company':sym['Security'],
                "Ticker":sym,
                "Last Closing":last_quote
            }
        )
    except:
        pass
    
SP500_Current_Price=pd.DataFrame(SP500_Current_Price)
            
    #print(symbol,round(last_quote,2))

# %%
SP500_Current_Price[:20]
# Out:
#    Ticker  Last Closing
# 0     MMM    148.649994
# 1     AOS     68.580002
# 2     ABT    120.620003
# 3    ABBV    147.770004
# 4    ABMD    310.739990
# 5     ACN    316.019989
# 6    ATVI     81.500000
# 7     ADM     78.449997
# 8    ADBE    467.679993
# 9     ADP    204.440002
# 10    AAP    204.479996
# 11    AES     21.230000
# 12    AFL     61.090000
# 13      A    130.360001
# 14    AIG     61.240002
# 15    APD    236.300003
# 16   AKAM    108.260002
# 17    ALK     56.139999
# 18    ALB    195.889999
# 19    ARE    189.399994

# %%
ticker = ['RY.TO','AC.TO','DOL.TO']
data = pd.DataFrame()
data[ticker] = yf.download(ticker, start = '2017-01-01', end = '2022-07-08')['Adj Close']
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#                 RY.TO      AC.TO      DOL.TO
# Date
# 2017-01-03  13.830000  32.265347   74.083336
# 2017-01-04  13.720000  32.569313   75.168266
# 2017-01-05  13.740000  32.517010   75.152092
# 2017-01-06  13.560000  32.507198   75.071121
# 2017-01-09  13.500000  32.242466   74.909164
# ...               ...        ...         ...
# 2022-06-30  16.040001  74.065231  124.639999
# 2022-07-04  16.230000  75.434212  125.690002
# 2022-07-05  16.389999  76.223633  124.870003
# 2022-07-06  16.469999  74.375000  125.540001
# 2022-07-07  16.660000  76.300003  127.480003
#
# [1384 rows x 3 columns]

# %%
returns = (data-data.shift(1))/data.shift(1)
returns.head(5)
# Out:
#                RY.TO     AC.TO    DOL.TO
# Date
# 2017-01-03       NaN       NaN       NaN
# 2017-01-04 -0.007954  0.009421  0.014645
# 2017-01-05  0.001458 -0.001606 -0.000215
# 2017-01-06 -0.013100 -0.000302 -0.001077
# 2017-01-09 -0.004425 -0.008144 -0.002157
